# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://data.cdc.gov/resource/cjae-szjv.json?"

# %%
# Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# [{'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1027', 'countyname': 'Clay', 'reportyear': '1999', 'value': '33', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1051', 'countyname': 'Elmore', 'reportyear': '1999', 'value': '5', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1073', 'countyname': 'Jefferson', 'reportyear': '1999', 'value': '39', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1079', 'countyname': 'Lawrence', 'reportyear': '1999', 'value': '28', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1089', 'countyname': 'Madison', 'reportyear': '1999', 'value': '31', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1097', 'countyname': 'Mobile', 'reportyear': '1999', 'value': '32', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1101', 'countyname': 'Montgomery', 'reportyear': '1999', 'value': '15', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1117', 'countyname': 'Shelby', 'reportyear': '1999', 'value': '45', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '83', 'measurename': 'Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard', 'measuretype': 'Counts', 'stratificationlevel': 'State x County', 'statefips': '1', 'statename': 'Alabama', 'countyfips': '1119', 'countyname': 'Sumter', 'reportyear': '1999', 'value': '3', 'unit': 'No Units', 'unitname': 'No Units', 'dataorigin': 'Monitor Only', 'monitoronly': '1'}, {'measureid': '84', 'measurename': 'Number of person-days with maximum 8-hour average o ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "33"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "39"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "28"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "31"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "32"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "15"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "45"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "3"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "467742"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "323340"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "25850955"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "967036"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "8515483"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "12778336"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "3353220"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6322590"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "44928"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "85",
#         "measurename": "Percent of days with PM2.5 levels over the National Ambient Air Quality Standard (NAAQS)",
#         "measuretype": "Percent",
#         "monitoronly": "1",
#         "reportyear": "2009",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "%",
#         "unitname": "Percent",
#         "value": "0"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "34"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "7"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "13"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "38"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "11"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "18"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "32"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "23"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "35"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "4805628"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "99841"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "860080"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "25157254"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "383614"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5004108"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "12802336"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5138844"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5063590"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "73730"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "4"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "19"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "1"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "9"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "4"
#     },
#     {
#         "countyfips": "1103",
#         "countyname": "Morgan",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "7"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "20"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "1"
#     },
#     {
#         "countyfips": "1125",
#         "countyname": "Tuscaloosa",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "869250"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "85788"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "269836"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "12543743"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "34870"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "2533653"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "2000645"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "892192"
#     },
#     {
#         "countyfips": "1103",
#         "countyname": "Morgan",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "781774"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "2987160"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "14630"
#     },
#     {
#         "countyfips": "1125",
#         "countyname": "Tuscaloosa",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2001",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "1001706"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "0"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "11"
#     },
#     {
#         "countyfips": "1033",
#         "countyname": "Colbert",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "13"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6"
#     },
#     {
#         "countyfips": "1055",
#         "countyname": "Etowah",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "7"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "26"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "7"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "8"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "6"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5"
#     },
#     {
#         "countyfips": "1103",
#         "countyname": "Morgan",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "15"
#     },
#     {
#         "countyfips": "1117",
#         "countyname": "Shelby",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "24"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "5"
#     },
#     {
#         "countyfips": "1125",
#         "countyname": "Tuscaloosa",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "10"
#     },
#     {
#         "countyfips": "1127",
#         "countyname": "Walker",
#         "dataorigin": "Monitor Only",
#         "measureid": "83",
#         "measurename": "Number of days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "13"
#     },
#     {
#         "countyfips": "1033",
#         "countyname": "Colbert",
#         "dataorigin": "Monitor Only",
#         "measureid": "85",
#         "measurename": "Percent of days with PM2.5 levels over the National Ambient Air Quality Standard (NAAQS)",
#         "measuretype": "Percent",
#         "monitoronly": "1",
#         "reportyear": "2013",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "%",
#         "unitname": "Percent",
#         "value": "0"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "0"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "156827"
#     },
#     {
#         "countyfips": "1033",
#         "countyname": "Colbert",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "708968"
#     },
#     {
#         "countyfips": "1051",
#         "countyname": "Elmore",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "411954"
#     },
#     {
#         "countyfips": "1055",
#         "countyname": "Etowah",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "720916"
#     },
#     {
#         "countyfips": "1073",
#         "countyname": "Jefferson",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "No Units",
#         "unitname": "No Units",
#         "value": "17095468"
#     },
#     {
#         "countyfips": "1079",
#         "countyname": "Lawrence",
#         "dataorigin": "Monitor Only",
#         "measureid": "84",
#         "measurename": "Number of person-days with maximum 8-hour average ozone concentration over the National Ambient Air Quality Standard",
#         "measuretype": "Counts",
# ...
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2013",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "8.0207738095238099"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2005",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "12.2536598020434"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2003",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "13.7725537634409"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2010",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "9.7841120689655199"
#     },
#     {
#         "countyfips": "1055",
#         "countyname": "Etowah",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2005",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "15.420892857142899"
#     },
#     {
#         "countyfips": "1049",
#         "countyname": "DeKalb",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "14.387033564261801"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2007",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "13.3713274008157"
#     },
#     {
#         "countyfips": "1121",
#         "countyname": "Talladega",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2002",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "14.113520430718699"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2007",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.45975"
#     },
#     {
#         "countyfips": "1127",
#         "countyname": "Walker",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2010",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.252277298850601"
#     },
#     {
#         "countyfips": "1049",
#         "countyname": "DeKalb",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "18.4047994987469"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2007",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "10.3625129399586"
#     },
#     {
#         "countyfips": "1069",
#         "countyname": "Houston",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2013",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "8.2777361751152103"
#     },
#     {
#         "countyfips": "1055",
#         "countyname": "Etowah",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2011",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.4310978835979"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2000",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "16.282090285502399"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2009",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.045689655172399"
#     },
#     {
#         "countyfips": "1119",
#         "countyname": "Sumter",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "1999",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "17.023375331564999"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2006",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "13.2604205069124"
#     },
#     {
#         "countyfips": "1003",
#         "countyname": "Baldwin",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2005",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.747826086956501"
#     },
#     {
#         "countyfips": "1125",
#         "countyname": "Tuscaloosa",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2010",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "11.042311827957001"
#     },
#     {
#         "countyfips": "1101",
#         "countyname": "Montgomery",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2007",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "14.5259535969967"
#     },
#     {
#         "countyfips": "1097",
#         "countyname": "Mobile",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2006",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "12.821995736003"
#     },
#     {
#         "countyfips": "1049",
#         "countyname": "DeKalb",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2005",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "14.224505336617399"
#     },
#     {
#         "countyfips": "1121",
#         "countyname": "Talladega",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2008",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "12.0902669632925"
#     },
#     {
#         "countyfips": "1027",
#         "countyname": "Clay",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2011",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "10.5599404761905"
#     },
#     {
#         "countyfips": "1089",
#         "countyname": "Madison",
#         "dataorigin": "Monitor Only",
#         "measureid": "87",
#         "measurename": "Annual average ambient concentrations of PM2.5 in micrograms per cubic meter (based on seasonal averages and daily measurement)",
#         "measuretype": "Average",
#         "monitoronly": "1",
#         "reportyear": "2012",
#         "statefips": "1",
#         "statename": "Alabama",
#         "stratificationlevel": "State x County",
#         "unit": "\u00b5g/m\u00b3",
#         "unitname": "Micograms per cubic meter",
#         "value": "9.2668335187245106"
#     }
# ]
